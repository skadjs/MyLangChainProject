# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add pypdf=">=4.2.0,<5.0.0"
# poetry add langchain-upstage

# %% [markdown]
# #### PyPDFLoader 간단한 예제

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
# Out:
# 24

# %% [markdown]
# #### Upstage 를 사용한 RAG
# * ChatUpstage
# * UpstageEmbeddings
# * UpstageDocumentParseLoader

# %%
#!pip install langchain_upstage

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings

print("==> 1. 문서 로딩 → PDF 읽기...")
file_path = "../data/tutorial-korean.pdf"
loader = PyPDFLoader(file_path)
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")
# Out:
# ==> 1. 문서 로딩 → PDF 읽기...
#   총 39페이지 로드 완료

# %%
print("==> 2. 문서 분할 → 작은 청크로 나누기")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        # 청크 크기 (한국어 최적화)
    chunk_overlap=200,      # 중복 부분 (맥락 보존)
    separators=["\n\n", "\n", ".", " ", ""] # 자연스러운 분할을 위한 구분자
)

chunks = text_splitter.split_documents(documents)
print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")
print(type(chunks[0]))
# Out:
# ==> 2. 문서 분할 → 작은 청크로 나누기
#   66개 청크 생성 완료
#   평균 청크 길이: 688자
# <class 'langchain_core.documents.base.Document'>

# %%
print("==> 3. 벡터화 → 임베딩으로 변환")
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")

print("==> 4. 저장 → FAISS 벡터스토어에 저장")
vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")
# 로컬 파일로 저장
vectorstore.save_local("faiss_db")

print("===> 5. 검색 → 질문과 유사한 문서 찾기")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}  # 상위 6개 관련 문서 검색
)
print(" Retriever 설정 완료")
# Out:
# ==> 3. 벡터화 → 임베딩으로 변환
# ==> 4. 저장 → FAISS 벡터스토어에 저장
#  FAISS 벡터스토어 생성 완료 (66개 벡터)
# ===> 5. 검색 → 질문과 유사한 문서 찾기
#  Retriever 설정 완료

# %%
print("===> 6. 생성 → LLM으로 답변 생성")
llm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=0.5
    )
print(llm)
# Out:
# ===> 6. 생성 → LLM으로 답변 생성
# client=<openai.resources.chat.completions.completions.Completions object at 0x10ad81ae0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x10ad806d0> model_name='solar-pro' temperature=0.5 model_kwargs={} upstage_api_key=SecretStr('**********') upstage_api_base='https://api.upstage.ai/v1'

# %%
# 한국어 최적화 프롬프트
prompt_template = """
당신은 BlueJ 프로그래밍 환경 전문가입니다. 
아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.

문서 내용:
{context}

질문: {question}

답변 규칙:
1. 문서 내용만을 근거로 답변하세요
2. 단계별 설명이 필요하면 순서대로 작성하세요  
3. 구체적인 메뉴명, 버튼명을 포함하세요
4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요

답변:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)
print(" 프롬프트 설정 완료")
print(prompt)
# Out:
#  프롬프트 설정 완료
# input_variables=['context', 'question'] input_types={} partial_variables={} template='\n당신은 BlueJ 프로그래밍 환경 전문가입니다. \n아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.\n\n문서 내용:\n{context}\n\n질문: {question}\n\n답변 규칙:\n1. 문서 내용만을 근거로 답변하세요\n2. 단계별 설명이 필요하면 순서대로 작성하세요  \n3. 구체적인 메뉴명, 버튼명을 포함하세요\n4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요\n\n답변:'

# %%
# ===================================
# 7. QA 체인 생성
# ===================================
print("\n ===> 7.  QA 체인 생성...")
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
print("  RAG 파이프라인 구축 완료!")

# ===================================
# 8. 테스트 질문들
# ===================================
test_questions = [
    "BlueJ에서 객체를 생성하는 방법은 무엇인가요?",
    "컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?", 
    "디버깅을 위해 중단점을 설정하는 방법을 알려주세요",
    "코드패드는 무엇이고 어떻게 사용하나요?",
    "애플릿을 만들고 실행하는 방법을 설명해주세요"
]

print("\n" + "=" * 60)
print(" RAG 시스템 테스트")
print("=" * 60)

# ===================================
# 9. 질문 및 답변 실행
# ===================================
for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = qa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#  ===> 7.  QA 체인 생성...
#   RAG 파이프라인 구축 완료!
#
# ============================================================
#  RAG 시스템 테스트
# ============================================================
#
# 【테스트 1/5】
#  질문: BlueJ에서 객체를 생성하는 방법은 무엇인가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 객체를 생성하는 방법은 다음과 같습니다. 문서 내용을 근거로 단계별로 설명드립니다:
#
# 1. **클래스 아이콘 우클릭**
#    메인 윈도우 중앙의 클래스 아이콘(예: `Person`, `Staff`)에서 마우스 오른쪽 버튼을 클릭합니다.
#    (맥 OS의 경우 `Ctrl+클릭`)
#
# 2. **생성자 선택**
#    팝업 메뉴에서 해당 클래스의 생성자(Constructor)를 선택합니다.
#    - 추상 클래스(`<<abstract>>` 표시)는 객체 생성이 불가능합니다.
#
# 3. **객체 이름 입력**
#    대화상자가 나타나면 생성할 객체의 이름을 입력합니다.
#    - 기본 이름(예: `staff_1`)이 제공되며, 필요 시 수정 후 **OK** 버튼을 클릭합니다.
#
# 4. **객체 생성 완료**
#    생성된 객체는 **오브젝트 벤치(Object Bench)**에 표시됩니다.
#    (예: 그림 4 참조)
#
# > **라이브러리 클래스 객체 생성 시 추가 방법**:
# > - **Tools - Use Libraries Class** 메뉴를 선택합니다.
# > - 패키지 이름 포함된 정확한 클래스명(예: `java.lang.String`)을 입력하고 엔터 키를 누릅니다.
# > - 생성자 또는 정적 메소드를 선택하여 호출할 수 있습니다.
#
# 문서에서 확인할 수 없는 내용은 "문서에서 찾을 수 없습니다"로 답변드립니다.
#
#  참조 문서:
#    1. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#    2. 페이지 35: 3610.6. 라이브러리 클래스로부터 객체생성하기 BlueJ 는 JDK에서 제공하는 라이브러리의 클래스들로부터 객체를 생성하기 위한 기능을  제...
#    3. 페이지 7: 83.2. 프로젝트 열기 프로젝트란, 관련 있는 여러개의 파일들을 묶어서 관리하기 위한 하나의 작업 단위를 말합니다.  BlueJ  프로젝트는 ...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 컴파일 오류가 발생했을 때 확인하는 방법은 다음과 같습니다.
#
# ### 1. **에디터 창에서 직접 확인**
#    - 오류가 발생한 클래스 파일을 **에디터에서 열면**, 정보 창(에디터 하단)에 다음 내용이 표시됩니다.
#      - **에러가 발생한 라인**이 반전(강조)됩니다.
#      - **에러 메시지**가 구체적으로 출력됩니다.
#    - 예시: 세미콜론(`;`) 누락 시 해당 라인과 함께 "Syntax error on token ..." 등의 메시지가 나타납니다.
#
# ### 2. **도움말 버튼 활용**
#    - 정보 창의 오른쪽 **물음표(`?`) 버튼**을 클릭하면, 해당 에러 메시지에 대한 추가 설명이 제공됩니다.
#      - *단, 모든 에러에 도움말이 제공되는 것은 아니며, 일부 미작성된 내용도 있습니다.*
#
# ### 3. **프로젝트 툴바의 Compile 버튼 사용 시**
#    - 여러 클래스를 수정한 후 **프로젝트 윈도우 툴바의 Compile 버튼**을 누르면:
#      - 전체 프로젝트가 컴파일되며, 오류가 있는 클래스가 있을 경우 해당 에디터가 자동으로 열립니다.
#      - 에디터에서 오류 위치와 메시지를 확인할 수 있습니다.
#
# ### 4. **주의사항**
#    - **오브젝트 벤치의 객체**는 클래스 수정 후 컴파일이 실패하면 사라집니다.
#    - 소스 코드는 자동으로 저장되므로, 별도로 저장할 필요는 없지만 시스템 불안정 시 **Class 메뉴 > 저장** 기능을 사용할 수 있습니다.
#
# > 문서에는 위 방법 외에 추가적인 디버깅 도구나 오류 분석 기능은 언급되지 않았습니다.
#
#  참조 문서:
#    1. 페이지 12: 클래스를 성공적으로 컴파일 하였다면 에디터를 닫으십시오.  프로젝트 윈도우에 툴바 역시 Compile 버튼을 가지고 있습니다. 이 컴파일 기능은...
#    2. 페이지 12: 13  노트 : 프로젝트를 처음 열었을 때 왜 클래스 아이콘에 체크표시가 되어있지 않은지 궁금할 수 있습니다. people  프로젝트 내의 클래...
#    3. 페이지 1: 3.7. 컴파일러 에러들에 관한 도움말 ······································· ··················...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 디버깅을 위해 중단점을 설정하는 방법을 알려주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 디버깅을 위해 **중단점(Breakpoint)**을 설정하는 방법은 다음과 같습니다. 문서 내용을 근거로 단계별로 설명드리겠습니다.
#
# ---
#
# ### 1. 중단점 설정 방법
# 1. **소스 코드 편집기 열기**
#    - `examples` 디렉토리의 `debugdemo` 프로젝트를 열고, `Demo` 클래스를 선택합니다.
#    - `loop` 메소드를 찾아 엽니다. (또는 다른 클래스의 소스 코드도 동일하게 적용 가능)
#
# 2. **중단점 영역 확인**
#    - 편집기 창의 **왼쪽 여백**(라인 번호 영역)을 확인합니다. 이 부분이 중단점 설정 영역입니다.
#
# 3. **중단점 설정**
#    - `for` 반복문 내부의 **임의의 라인**에서 왼쪽 여백을 **마우스 왼쪽 버튼으로 클릭**합니다.
#    - 클릭 시 해당 라인에 **작은 "stop" 표시**(빨간 원)가 나타나며, 중단점이 설정됩니다.
#      (예: `sum += i;` 라인에 중단점 설정)
#
# ---
#
# ### 2. 중단점 동작 확인
# 1. **프로그램 실행**
#    - `Demo` 클래스에서 객체를 생성한 후, `loop(10)` 메소드를 호출합니다.
#    - 프로그램이 실행되면 설정된 중단점에 도달할 때까지 자동으로 실행됩니다.
#
# 2. **디버깅 모드 진입**
#    - 중단점에 도달하면:
#      - 실행 중인 **현재 라인**이 반전된 상태로 표시됩니다.
#      - **디버거 윈도우**가 자동으로 열리며, 변수 값을 확인할 수 있습니다.
#
# ---
#
# ### 3. 중단점 제거
# - 설정된 중단점을 제거하려면, 해당 라인의 왼쪽 여백(**"stop" 표시**)을 다시 **마우스 왼쪽 버튼으로 클릭**합니다.
# - "stop" 표시가 사라지며 중단점이 해제됩니다.
#
# ---
#
# ### 참고 사항
# - 중단점은 **소스 코드의 실행 가능한 라인**에만 설정할 수 있습니다 (예: 변수 선언, 반복문, 조건문 등).
# - 중단점 설정/해제는 **디버깅 세션 중에도 가능**합니다.
# - 문서에서 명시되지 않은 다른 기능(예: 조건부 중단점)은 지원하지 않습니다.
#
# > 📌 **문서에서 찾을 수 없는 정보**:
# > - 단축키(예: `Ctrl+Shift+B`)로 중단점을 설정하는 방법은 문서에 언급되지 않았습니다.
# > - 중단점 일시 활성화/비활성화 기능은 문서에서 다루지 않습니다.
#
#  참조 문서:
#    1. 페이지 25: 267. 디버깅 이 절에서는, BlueJ의 디버깅에 관한 기능들 중에서 가장 중요한 측면을 소개합니다. 컴퓨터  프로그래밍 담당 선생님들은 첫 ...
#    2. 페이지 2: 37. 디버깅 ························································· ··············...
#    3. 페이지 25: 마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다. 바로 시도해 봅시다. Demo  클래...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 코드패드는 무엇이고 어떻게 사용하나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 코드패드란?
# **코드패드**는 BlueJ에서 자바 코드(표현식 또는 명령문)를 실시간으로 평가하고 테스트할 수 있는 도구입니다. 프로그램 코드의 동작을 조사하거나 구문을 시험해보는 데 유용하며, 간단한 계산부터 객체 생성 및 메소드 호출까지 다양한 작업이 가능합니다.
#
# ---
#
# ### 코드패드 사용 방법
#
# #### 1. **코드패드 열기**
# - **단계**:
#   1. BlueJ 메인 화면에서 **보기(Show) 메뉴**를 클릭합니다.
#   2. **코드패드 보기(Show Code Pad)**를 선택합니다.
# - **위치**: 코드패드는 메인 화면의 **오른쪽 아래**(오브젝트 벤치 옆)에 표시됩니다.
# - **크기 조정**: 코드패드와 오브젝트 벤치 사이의 가로/세로 선을 드래그하여 크기를 조절할 수 있습니다.
#
# #### 2. **표현식/명령문 입력 및 실행**
# - **입력**: 코드패드 영역에 자바 표현식 또는 명령문을 입력합니다.
#   - 예: `4 + 45`, `"hello".length()`, `new Student()`
# - **실행**:
#   - **Enter 키**를 눌러 한 줄씩 실행합니다.
#   - **멀티라인 명령문**은 마지막 줄을 제외한 각 줄 끝에서 **Shift + Enter**를 누른 후 마지막 줄에서 Enter를 누릅니다.
# - **결과 확인**:
#   - 결과는 코드패드에 표시되며, 타입이 괄호 안에 함께 출력됩니다(예: `50 (int)`).
#   - 객체 생성 시 결과 라인에 **작은 객체 아이콘**이 나타납니다.
#
# #### 3. **객체 관리**
# - **오브젝트 벤치로 이동**:
#   1. 코드패드에서 생성된 객체의 아이콘을 **드래그**하여 오브젝트 벤치로 옮깁니다.
#   2. 이후 팝업 메뉴 또는 코드패드에서 해당 객체의 메소드를 호출할 수 있습니다.
# - **객체 검사**:
#   - 코드패드의 객체 아이콘을 **더블클릭**하면 객체 상태 검사 화면이 열립니다.
#
# #### 4. **입력 이력 활용**
# - **이전 입력 재사용**:
#   - **상하 화살표 키**로 이전에 입력한 코드를 탐색하고 수정할 수 있습니다.
#
# #### 5. **주의사항**
# - **변수 범위**:
#   - 코드패드에서 선언된 지역변수는 **다른 라인에서 재사용할 수 없습니다**.
#   - 오브젝트 벤치의 객체는 인스턴스 필드처럼 참조 가능합니다.
# - **멀티라인 오류 방지**:
#   - 서로 다른 메소드의 코드를 한 코드패드에서 실행할 경우 변수 참조 오류가 발생할 수 있습니다.
#
# ---
#
# ### 예시
# 1. **표현식 평가**:
#    - 입력: `Math.max(33, 4)` → 결과: `33 (int)`
# 2. **객체 생성**:
#    - 입력: `new java.util.Random()` → 결과: `<object reference> (java.util.Random)`
# 3. **메소드 호출**:
#    - 오브젝트 벤치에 `student1` 객체가 있을 때:
#      입력: `student1.getName()` → 결과: `"John" (java.lang.String)`
#
# > 문서에서 찾을 수 없는 추가 기능(예: 디버깅 지원)은 BlueJ 기본 문서 범위를 벗어납니다.
#
#  참조 문서:
#    1. 페이지 1: 5.2. 클래스 만들기 ················································ ··················...
#    2. 페이지 20: 216. 코드패드의 사용 BlueJ 코드패드는 자바 코드(표현식과 명령문)의 일부분을 쉽고 빠르게 평가할 수 있는 기능을  제공합니다. 따라서,...
#    3. 페이지 36: 15. 코드패드로부터 객체를 오브젝트 벤치로 이동하기 위해서는 객체아이콘을 드래그 하십시오. 16. 코드패드에서 생성된 객체를 검사하기 위해서는...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 애플릿을 만들고 실행하는 방법을 설명해주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### BlueJ에서 애플릿을 만들고 실행하는 방법 (문서 내용 기준)
#
# ---
#
# #### 1. **애플릿 만들기**
# 1. **새 클래스 생성**
#    - BlueJ 메인 화면에서 **"New Class"** 버튼을 클릭합니다.
#    - 대화상자에서 클래스 이름을 입력하고, **"Type"** 드롭다운 메뉴에서 **"Applet"**을 선택합니다.
#    - "OK"를 클릭하여 애플릿 클래스를 생성합니다.
#      → 기본 골격 코드가 포함된 애플릿 클래스가 생성됩니다.
#      - 주요 메서드: `paint()` (샘플 코드가 포함됨), 생성자 등.
#      - 주석으로 각 메서드의 목적이 설명되어 있습니다.
#
# 2. **코드 편집**
#    - 생성된 클래스를 더블클릭하여 에디터를 열고, `paint()` 메서드 등에 원하는 코드를 추가합니다.
#    - 예: 그래픽 출력, 사용자 인터페이스 요소 구현.
#
# ---
#
# #### 2. **애플릿 실행하기**
# 1. **컴파일**
#    - 클래스 아이콘에서 마우스 오른쪽 버튼 클릭 → **"Compile"**을 선택하여 코드를 컴파일합니다.
#    - 컴파일 성공 시 클래스 아이콘에 <<applet>> 태그가 표시됩니다.
#
# 2. **실행 방법 선택**
#    - 클래스 아이콘에서 마우스 오른쪽 버튼 클릭 → **"Run Applet"**을 선택합니다.
#    - 실행 옵션 대화상자가 나타납니다:
#      - **"Applet Viewer"**: JDK 내장 뷰어 사용 (권장, 버전 호환성 문제 적음).
#      - **"Web Browser"**: 기본 브라우저 사용 (윈도우/Mac) 또는 설정 파일 정의 브라우저 (유닉스).
#      - **"Generate HTML"**: 웹페이지만 생성 (실행하지 않음).
#    - 옵션을 선택하고 **"OK"**를 클릭합니다.
#      → 애플릿 뷰어 또는 브라우저에서 애플릿이 실행됩니다.
#
# ---
#
# #### 3. **애플릿 테스트하기**
# 1. **객체 벤치 사용**
#    - 애플릿 객체를 오브젝트 벤치에 생성하면 일부 메서드를 테스트할 수 있습니다.
#      - 클래스 아이콘에서 마우스 오른쪽 버튼 → **"new [클래스명]()"**으로 객체 생성.
#    - 단, 오브젝트 벤치에서는 애플릿을 **완전히 실행할 수 없습니다** (GUI 표시 불가).
#
# 2. **디버깅 주의사항**
#    - 애플릿 뷰어/브라우저에서 실행 시 BlueJ의 **중단점(Breakpoint)이 무시됩니다**.
#    - 디버깅이 필요한 경우:
#      - Michael Trigoboff의 **AppletWindow** 클래스를 사용해야 합니다.
#      - 이 클래스는 BlueJ 홈페이지의 "Resources" 메뉴에서 다운로드 가능합니다.
#      - AppletWindow를 이용하면 BlueJ 환경에서 직접 애플릿을 실행하고 디버깅할 수 있습니다.
#
# ---
#
# #### 4. **예제 프로젝트 활용**
# - 문서 예제: `examples/appletdemo` 프로젝트의 `CaseConverter` 클래스를 참고하세요.
#   - 이 클래스는 애플릿 실행 및 HTML 생성 절차를 보여줍니다.
#
# ---
#
# ### 요약
# 1. **애플릿 생성**: New Class → Type: Applet 선택.
# 2. **실행**: Run Applet → Applet Viewer 또는 브라우저 선택.
# 3. **테스트**: 오브젝트 벤치에서 메서드 실행 또는 AppletWindow로 디버깅.
# 4. **주의**: 브라우저 실행 시 중단점 미지원.
#
# > 문서에 명시되지 않은 추가 기능(예: HTML 파일 수동 생성 방법)은 "문서에서 찾을 수 없습니다".
#
#  참조 문서:
#    1. 페이지 32: 33마이크로소프트 윈도우즈나 MAC OS시스템에서, BlueJ 는 여러분의 기본 브라우저를 사용 합니다. 유닉스 시스템의 경우는, BlueJ 설...
#    2. 페이지 31: 329. 애플릿 만들기 9.1. 애플릿 실행하기     BuleJ 는 어플리케이션 뿐만 아니라 애플릿을 만들고, 실행할 수 있습니다. 예제(ex...
#    3. 페이지 2: 8. 독립형 어플리케이션 생성 ··············································· ···············...
#
# ----------------------------------------

# %%
from langchain_upstage import UpstageGroundednessCheck

groundedness_check = UpstageGroundednessCheck()

#Grounded
question = "BlueJ에서 객체를 생성하는 방법은 무엇인가요?"

#notGrounded
question = "현재의 기온은 몇도 인가요?"  

retrieved_docs = retriever.invoke(question)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response = llm.invoke(f"{question} 관련 정보: {context}")

request_input = {
    "context": context,
    "answer": response.content
}

response = groundedness_check.invoke(request_input)
print(response)
# Out:
# grounded
