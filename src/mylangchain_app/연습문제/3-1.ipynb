# %% [markdown]
# ### 문제 3-1 : 콘텐츠분쟁해결 RAG 시스템 - 간단 실습 가이드

# %%
import os
import time
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import UpstageEmbeddings, ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from pprint import pprint

# %%
def setup_environment():
    if not load_dotenv():
        print("'.env' 파일을 찾을 수 없습니다. 환경 변수를 수동으로 설정해주세요.")
        return False
    
    if "UPSTAGE_API_KEY" not in os.environ:
        print("UPSTAGE_API_KEY가 .env 파일에 없습니다. 키를 추가해주세요.")
        return False
        
    print("API 키가 성공적으로 로드되었습니다.")
    return True

# %%
def classify_dispute_type(query):
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
    
    query_lower = query.lower()
    
    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"
    else:
        return "기타"

# %%
def main():
    if not setup_environment():
        return

    print("\n--- 0단계: 문서 로드 ---")
    start_time = time.time()
    try:
        loader = PyPDFLoader("/Users/eon/skRookies/myLangChain/mylangchain-app/src/mylangchain_app/data/콘텐츠분쟁해결_사례.pdf")
        documents = loader.load()
        print(f"PDF 문서 로딩 완료. 총 {len(documents)} 페이지. (소요 시간: {time.time() - start_time:.2f}초)")
    except Exception as e:
        print(f"PDF 로딩 중 오류 발생: {e}")
        return

    print("\n--- 1단계: 문서 분할 ---")
    start_time = time.time()
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1500,
        chunk_overlap=300,
        separators=[
            "\n【사건개요】",
            "\n【쟁점사항】",
            "\n【처리경위】",
            "\n【처리결과】",
            "\n■", "\n\n", "\n", ".", " ", ""
        ]
    )

    split_docs = text_splitter.split_documents(documents)
    print(f"문서 분할 완료. 총 {len(split_docs)}개의 청크 생성. (소요 시간: {time.time() - start_time:.2f}초)")

    print("\n--- 2단계: 임베딩 모델 설정 ---")
    embeddings = UpstageEmbeddings(model="solar-embedding-1-large")
    print(f"임베딩 모델 '{embeddings.model}'이 설정되었습니다.")

    print("\n--- 3단계: 벡터 DB 생성 및 검색기 설정 ---")
    start_time = time.time()
    vectorstore = FAISS.from_documents(documents=split_docs, embedding=embeddings)
    retriever = vectorstore.as_retriever(
        search_type="similarity",
        search_kwargs={"k": 5}
    )
    print(f"FAISS 벡터 DB 및 검색기 생성 완료. (소요 시간: {time.time() - start_time:.2f}초)")

    print("\n--- 4단계: LLM 설정 ---")
    llm = ChatUpstage(
        model="solar-pro",
        temperature=0.2
    )
    print(f"LLM '{llm.model_name}'이 설정되었습니다.")

    print("\n--- 5단계: 프롬프트 템플릿 작성 ---")
    prompt_template = """
    당신은 콘텐츠 분야 전문 법률 자문가입니다. 
    아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해 주세요.

    관련 분쟁사례:
    {context}

    상담 내용: {question}

    답변 가이드라인:
    1. 제시된 사례들을 근거로 답변하세요
    2. 관련 법령이나 조항이 있다면 명시하세요
    3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요
    4. 실무적 해결방안을 단계별로 제시하세요
    5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요

    전문 법률 조언:"""
    
    prompt = PromptTemplate.from_template(prompt_template)
    print("법률 자문 프롬프트가 준비되었습니다.")

    # 6단계: QA 체인 생성
    print("\n--- 6단계: RAG QA 체인 생성 ---")
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        chain_type_kwargs={"prompt": prompt},
        return_source_documents=True
    )
    print("RetrievalQA 체인이 성공적으로 생성되었습니다.")

    print("\n--- 7 & 8단계: 테스트 질문 실행 및 분쟁 유형 분류 ---")
    test_questions = [
        "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
        "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
        "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
        "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
        "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
    ]

    for i, question in enumerate(test_questions):
        print(f"\n{'='*20} 테스트 질문 {i+1} {'='*20}")
        
        # 8단계: 분쟁 유형 분류
        dispute_type = classify_dispute_type(question)
        print(f"질문: {question}")
        print(f"예상 분쟁 유형: {dispute_type}")
        print("-" * 50)
        
        # QA 체인 실행
        start_time = time.time()
        result = qa_chain.invoke({"query": question})
        end_time = time.time()

        print(f"[전문 법률 조언 답변] (생성 시간: {end_time - start_time:.2f}초)")
        pprint(result["result"])

        print("\n[참조된 원본 문서]")
        # 참조된 소스 문서들의 출처와 내용 일부를 출력
        unique_sources = {}
        for doc in result["source_documents"]:
            source_page = f"페이지: {doc.metadata.get('page', 'N/A')}"
            if source_page not in unique_sources:
                 unique_sources[source_page] = doc.page_content[:200] + "..."
        
        for source, content in unique_sources.items():
            print(f"- {source}")
            # print(f"  내용: {content}") # 더 자세한 내용을 보고 싶으면 주석 해제

    print(f"\n{'='*20} 모든 테스트 완료 {'='*20}")

if __name__ == "__main__":
    main()
# Out:
# API 키가 성공적으로 로드되었습니다.
#
# --- 0단계: 문서 로드 ---
# PDF 문서 로딩 완료. 총 109 페이지. (소요 시간: 1.57초)
#
# --- 1단계: 문서 분할 ---
# 문서 분할 완료. 총 104개의 청크 생성. (소요 시간: 0.00초)
#
# --- 2단계: 임베딩 모델 설정 ---
# 임베딩 모델 'solar-embedding-1-large'이 설정되었습니다.
#
# --- 3단계: 벡터 DB 생성 및 검색기 설정 ---
# FAISS 벡터 DB 및 검색기 생성 완료. (소요 시간: 15.29초)
#
# --- 4단계: LLM 설정 ---
# LLM 'solar-pro'이 설정되었습니다.
#
# --- 5단계: 프롬프트 템플릿 작성 ---
# 법률 자문 프롬프트가 준비되었습니다.
#
# --- 6단계: RAG QA 체인 생성 ---
# RetrievalQA 체인이 성공적으로 생성되었습니다.
#
# --- 7 & 8단계: 테스트 질문 실행 및 분쟁 유형 분류 ---
#
# ==================== 테스트 질문 1 ====================
# 질문: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
# 예상 분쟁 유형: 게임
# --------------------------------------------------
# [전문 법률 조언 답변] (생성 시간: 9.09초)
# ('### 전문 법률 조언: 온라인 게임 시스템 오류로 인한 아이템 복구 거부 시 해결 방안  \n'
#  '\n'
#  '#### 1. **사례 분석을 통한 법적 쟁점**  \n'
#  '제시된 사례(2006, 2009년 시스템 오류 사례 등)에 따르면, 게임사의 시스템 오류로 인한 아이템 복구 여부는 다음 요소에 따라 '
#  '결정됩니다:  \n'
#  '- **(1) 오류 인정 여부**: 게임사가 시스템 오류를 공식적으로 인정하는지 (예: 2006년 사례에서는 복구 수용, 2009년 '
#  '사례에서는 오류 부인).  \n'
#  '- **(2) 계정 소유권**: 신청인이 계정 명의자인지 여부 (2006년 사례에서 명의 불일치 시 복구 거부).  \n'
#  '- **(3) 이용약관 조항**: 게임사가 "아이템 소유권" 또는 "오류 책임"을 약관에서 어떻게 규정했는지 (예: 2007년 사례에서 '
#  '아이템 회수 정당성 인정).  \n'
#  '\n'
#  '#### 2. **관련 법령 및 약관 검토**  \n'
#  '- **민법 제250조(도품·유실물 특례)**:  \n'
#  '  - 게임 아이템이 "금전"이 아닌 경우, 피해자(아이템 소유자)는 도난/유실 후 2년 내 반환 청구 가능.  \n'
#  '  - 단, **게임사는 일반적으로 이용약관에서 "아이템 소유권"을 보유**하므로, 민법상 반환 청구는 어려울 수 있음.  \n'
#  '- **전자상거래법 제17조(디지털콘텐츠 공급자의 의무)**:  \n'
#  '  - 시스템 오류로 인한 피해 시, 게임사는 "합리적 조치"를 취해야 하나, 구체적 보상 기준은 약관에 따름.  \n'
#  '- **게임 이용약관**:  \n'
#  '  - 대부분의 게임사는 "아이템 소유권"을 보유하며, 시스템 오류 시 복구 의무를 명시하지 않거나 "최선의 노력"만 규정함.  \n'
#  '\n'
#  '#### 3. **실무적 해결 단계**  \n'
#  '**(1) 증거 수집**  \n'
#  '- 시스템 오류 발생 시점, 아이템 소멸 전후 스크린샷, 게임사와의 문의 기록(채팅/이메일) 등을 확보.  \n'
#  '- **2006년 사례**에서는 피신청인이 오류를 인정하고 복구한 사례가 있으므로, 오류 증거를 제시하는 것이 중요.  \n'
#  '\n'
#  '**(2) 게임사에 공식 이의제기**  \n'
#  '- 고객센터 또는 게시판을 통해 **서면으로 복구 요청** (2006년 사례에서 게시판 문의 후 복구 성공).  \n'
#  '- 이용약관의 "고객 지원" 조항을 근거로 신속한 조치를 요구.  \n'
#  '\n'
#  '**(3) 계정 소유권 확인**  \n'
#  '- 계정 명의자와 실사용자가 다를 경우, 복구 거부 가능성 높음(2006년 사례 참조).  \n'
#  '- 명의 변경 절차(본인 인증 등)를 이행한 후 재요청.  \n'
#  '\n'
#  '**(4) 분쟁조정 신청**  \n'
#  '- 게임사가 복구 거부할 경우, **한국소비자원 또는 콘텐츠분쟁조정위원회**에 조정 신청.  \n'
#  '  - **2009년 사례**에서는 시스템 오류 증거가 부족해 조정 실패했으나, 명확한 증거가 있다면 결과 달라질 수 있음.  \n'
#  '  - 조정 시 **전자상거래법** 및 **약관의 불공정 조항**을 근거로 주장 가능.  \n'
#  '\n'
#  '**(5) 소송 고려**  \n'
#  '- 조정 실패 시, **민사소송**을 통해 피해 보상 청구 가능.  \n'
#  '  - 단, 게임사가 "아이템 소유권"을 약관으로 명시한 경우 승소 가능성 낮음.  \n'
#  '  - **2007년 사례**에서 해킹 아이템 회수 시 게임머니만 환급된 점을 참고해, 현금 결제 아이템인 경우 부분적 보상 가능성 '
#  '검토.  \n'
#  '\n'
#  '#### 4. **주의사항**  \n'
#  '- **제시된 사례집에는 없는 내용**:  \n'
#  '  - 게임사가 복구 비용을 청구하는 경우, 또는 아이템의 시장 가치를 기준으로 한 보상 여부.  \n'
#  '  - 블록체인 기반 NFT 아이템 등 "소유권 이전"이 명확한 경우와는 법적 접근이 상이함.  \n'
#  '\n'
#  '#### 5. **결론**  \n'
#  '- **최선의 방안**: 게임사의 시스템 오류 인정 및 복구 약속(2006년 사례)을 이끌어내기 위해 증거를 체계적으로 제시.  \n'
#  '- **현실적 한계**: 대부분의 게임사는 약관으로 책임을 제한하므로, 조정 또는 소송을 통한 보상은 어려울 수 있음.  \n'
#  '- **예방 조치**: 향후 게임 이용 시 **현금 결제 아이템은 반드시 영수증 보관**, 계정 공유 금지, 이용약관 내 "오류 책임" '
#  '조항 확인.  \n'
#  '\n'
#  '> ✅ **추천 조치**: 한국소비자원(☎ 1372) 또는 콘텐츠분쟁조정위원회(☎ 1670-4964)에 상담 신청 후, 게임사의 오류 '
#  '인정 여부를 집중적으로 질의하세요.')
#
# [참조된 원본 문서]
# - 페이지: 8
# - 페이지: 28
# - 페이지: 2
# - 페이지: 9
# - 페이지: 10
#
# ==================== 테스트 질문 2 ====================
# 질문: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
# 예상 분쟁 유형: 이러닝
# --------------------------------------------------
# [전문 법률 조언 답변] (생성 시간: 10.44초)
# ('### 전문 법률 조언: 인터넷 강의 중도 해지 시 과도한 위약금 요구 문제\n'
#  '\n'
#  '#### 1. **사례 분석 및 법적 근거**\n'
#  '제시된 사례들(2007~2010년 한국소비자원 조정결정례)에 따르면, **온라인 교육 서비스 중도 해지 시 과도한 위약금 요구는 대부분 '
#  '부당**으로 판단되었습니다. 주요 법적 근거는 다음과 같습니다.\n'
#  '\n'
#  '- **방문판매 등에 관한 법률 제30조(계약 해지/해제 효과)**  \n'
#  '  - "계속거래 계약 해지 시 소비자에게 **현저하게 초과**하는 위약금을 청구하거나, 실제 제공된 서비스 대가를 초과한 대금 반환을 '
#  '거부할 수 없음"을 명시합니다.  \n'
#  '  - 예시: 2007_온라인통신교육서비스 대금 환급 요구2 사례에서 피신청인의 위약금 공제가 방판법 위반으로 판단되었습니다.\n'
#  '\n'
#  '- **소비자분쟁해결기준(공정위 고시, 인터넷콘텐츠업)**  \n'
#  '  - 해지일까지의 **이용일수 해당 금액 + 총 이용금액의 10% 이내**만 공제 가능하며, 사은품은 미사용 시 반환해야 합니다.  \n'
#  '  - 예시: 2007_인터넷교육서비스 중도해지 요구 사례에서 소비자피해보상규정이 적용되어 피신청인의 과도한 공제가 기각되었습니다.\n'
#  '\n'
#  '- **소비자기본법 시행령 제10조**  \n'
#  '  - 환급금 산정 시 **계약서에 기재된 실제 지불 금액**을 기준으로 해야 하며, 피신청인이 임의로 추가 비용(컨텐츠비, 포맷비 '
#  '등)을 공제할 수 없습니다.  \n'
#  '  - 예시: 2008_온라인통신교육서비스 이용료 환급 요구2 사례에서 계약서상 금액과 실제 지불액 차이로 인해 피신청인의 주장이 '
#  '기각되었습니다.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 2. **실무적 해결 방안 (단계별)**\n'
#  '\n'
#  '**1단계: 계약서 및 증빙 자료 확인**  \n'
#  '- 계약서상 **명시된 총 금액**, **이용기간**, **해지 조건**을 확인합니다.  \n'
#  '- 실제 지불한 금액(할인 적용 여부)과 계약서 금액이 일치하는지 확인합니다.  \n'
#  '  - *예시: 2008년 사례에서 피신청인이 계약서상 금액(1,560,000원)과 실제 지불액(1,050,000원)을 달리 적용해 부당 '
#  '공제를 시도했으나 기각됨.*\n'
#  '\n'
#  '**2단계: 이용일수 및 공제 가능 항목 산정**  \n'
#  '- **이용일수**: 서비스 실제 이용 시작일(개통일)부터 해지 통보일까지의 기간을 계산합니다.  \n'
#  '  - *예시: 2010_인터넷 화상 강의 환급 요구 사례에서 "서비스 개통일"을 기준으로 이용일수를 산정함.*  \n'
#  '- **공제 가능 항목**:  \n'
#  '  - 이용일수 해당 금액 + 총 금액의 **10% 이내 위약금**만 공제 가능합니다.  \n'
#  '  - 추가 비용(컨텐츠비, 가입비, 사은품 비용 등)은 **계약서에 명시되지 않았거나 소비자가 실제로 사용하지 않은 경우 공제 '
#  '불가**합니다.  \n'
#  '    - *예시: 2007_인터넷교육서비스 중도해지 요구 사례에서 사은품 미사용 시 반환 의무가 인정됨.*\n'
#  '\n'
#  '**3단계: 해지 통보 방식 확인**  \n'
#  '- **구두 통보**만으로는 증거 부재로 분쟁 가능성이 있으므로, **내용증명우편** 또는 **이메일**로 해지 의사를 명확히 전달해야 '
#  '합니다.  \n'
#  '  - *예시: 2010_인터넷 화상 강의 환급 요구 사례에서 구두 통보 후 내용증명으로 재확인한 점이 중요하게 작용함.*\n'
#  '\n'
#  '**4단계: 환급금 계산 예시**  \n'
#  '- **가정**: 12개월 계약(1,200,000원)을 3개월 후 해지하고, 실제 이용일수 90일인 경우  \n'
#  '  - 이용금액: (1,200,000원 ÷ 365일) × 90일 = **295,890원**  \n'
#  '  - 위약금: 1,200,000원 × 10% = **120,000원**  \n'
#  '  - 환급금: 1,200,000원 - (295,890원 + 120,000원) = **784,110원**  \n'
#  '  - *단, 사은품 미반환 시 해당 금액 추가 공제 가능.*\n'
#  '\n'
#  '**5단계: 분쟁 발생 시 조치**  \n'
#  '- 피신청인이 부당한 공제를 주장할 경우, **한국소비자원(☎ 1372)** 또는 **소비자분쟁조정위원회**에 조정을 신청합니다.  \n'
#  '- 신용카드 할부 결제 시 **신용카드사 청구 철회 요청**도 가능합니다(할부금 잔여분 환급).\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 3. **주의사항**  \n'
#  '- **계약서에 해지 조건이 명시되지 않은 경우** 소비자분쟁해결기준이 우선 적용됩니다.  \n'
#  '- **사례집에 없는 내용**(예: 해외 서비스, B2B 계약 등)은 별도의 법적 검토가 필요합니다.  \n'
#  '- 위약금이 총 금액의 **10%를 초과**하거나, **실제 이용 금액 + 10%를 넘는 공제**는 법적 효력이 없습니다.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 결론  \n'
#  '과도한 위약금 요구는 **방판법 및 소비자분쟁해결기준에 위반**될 가능성이 높습니다. 계약서 내용과 실제 이용 내역을 근거로 공제 항목을 '
#  '재검토하고, 분쟁 시 소비자 보호 기관의 도움을 받는 것이 권장됩니다.')
#
# [참조된 원본 문서]
# - 페이지: 3
# - 페이지: 62
# - 페이지: 60
# - 페이지: 72
# - 페이지: 66
#
# ==================== 테스트 질문 3 ====================
# 질문: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
# 예상 분쟁 유형: 이러닝
# --------------------------------------------------
# [전문 법률 조언 답변] (생성 시간: 8.40초)
# ('### 전문 법률 조언: 무료체험 후 자동 유료전환 및 환불 요건 분석\n'
#  '\n'
#  '#### 1. **사례 근거 및 법적 쟁점**  \n'
#  '제시된 사례(한국소비자원 2010_무료 이벤트 후 자동 소액 결제 요금 환급요구, 전자거래분쟁조정위원회 2006_무료 광고 후 서비스 '
#  '이용요금 청구)에 따르면, **무료체험 후 자동 유료전환** 시 다음과 같은 요건이 충족되어야 사업자의 책임이 인정됩니다:  \n'
#  '- **중요사항 고지의무 위반**: 유료전환 조건, 해지 방법, 결제 시점 등이 명확히 고지되지 않았거나 소비자가 인지하기 어려운 '
#  '경우(예: 작은 글씨, 복잡한 절차).  \n'
#  '- **소비자 동의 여부**: 무료체험 가입 시 이용약관에 동의했더라도, 유료전환에 대한 구체적 설명이 누락된 경우 계약상 하자로 볼 수 '
#  '있음.  \n'
#  '- **소비자 과실**: 유료전환을 인지할 수 있는 충분한 고지(이벤트명, 공지사항 등)가 있었음에도 소비자가 확인하지 않은 경우, '
#  '책임이 일부 감소될 수 있음.\n'
#  '\n'
#  '> **관련 법령**  \n'
#  '> - **약관의 규제에 관한 법률 제3조**: 사업자는 계약 체결 시 중요 내용을 명확히 설명해야 하며, 소비자가 이해할 수 있도록 '
#  '고지해야 함.  \n'
#  '> - **소비자기본법 제18조(소비자분쟁해결기준)**: 부당한 계약 조건이나 고지 누락 시 환급 또는 계약 취소 가능.  \n'
#  '> - **표시·광고의 공정화에 관한 법률**: 허위·과장 광고로 소비자를 유인한 경우 시정조치 또는 손해배상 책임 발생.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 2. **유사 사례 처리 결과**  \n'
#  '- **한국소비자원 사례(2010)**:  \n'
#  '  - 사업자가 이벤트 화면에 유료전환 사실을 고지했으나, 글씨 크기가 작고 해지 방법이 불분명하여 **책임 50%** 인정.  \n'
#  '  - 결과: 4개월 분 요금(30,800원)의 50%(15,400원) 환급.  \n'
#  '- **전자거래분쟁조정위원회 사례(2006)**:  \n'
#  '  - 무료 광고로 유인한 후 유료결제를 요구했으나, 고지 내용이 불명확하여 **전액 환불** 권고.  \n'
#  '\n'
#  '→ **공통점**: 고지 불충분 시 사업자 책임 인정, 단 소비자 과실(확인 소홀)이 있을 경우 책임 비율 조정.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 3. **실무적 해결방안 (단계별)**  \n'
#  '**(1) 증거 수집**  \n'
#  '- 무료체험 가입 시 제공된 **이용약관**, **이벤트 공지**, **결제 내역** 등을 확보.  \n'
#  '- 유료전환 고지 여부(위치, 크기, 명확성)와 해지 방법(전화번호, 버튼 위치 등)을 확인.  \n'
#  '\n'
#  '**(2) 사업자와의 협의**  \n'
#  '- **고지 불충분**을 이유로 전액 또는 부분 환불을 요구.  \n'
#  '- 예시: "이용약관에 유료전환 조건이 명시되지 않았거나, 해지 방법이 불분명하여 계약상 하자가 있습니다."  \n'
#  '- **소비자분쟁조정위원회** 또는 **한국소비자원**에 조정 신청 가능성 언급.  \n'
#  '\n'
#  '**(3) 법적 조치**  \n'
#  '- 협의 실패 시 **소비자분쟁조정위원회**에 조정 신청.  \n'
#  '  - 조정 결과: 과거 사례와 유사하게 **30~70% 환급** 가능성 높음.  \n'
#  '- **소액사건처리절차법**에 따라 2천만 원 미만 분쟁은 간이 절차로 소송 가능.  \n'
#  '\n'
#  '**(4) 예방 조치**  \n'
#  '- 무료체험 가입 시 **유료전환 조건**을 반드시 확인.  \n'
#  '- **해지 방법**과 **결제 일자**를 스크린샷 등으로 보관.  \n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 4. **주의사항**  \n'
#  '- **제시된 사례집에는 없는 내용**:  \n'
#  '  - 자동결제 취소 권한(예: 통신사 소액결제 분쟁), 개인정보 보호법 위반(주민번호 수집) 등 추가적 법적 검토는 사례집에서 확인할 '
#  '수 없음.  \n'
#  '- **공정위 시정조치(2009)**: 무료체험 이벤트 시 유료전환 강제 조항이나 중도해지 제한은 무효화될 수 있음.  \n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 결론  \n'
#  '**"무료체험 후 자동 유료전환"**으로 인한 요금 청구 시, **고지 불충분**을 입증하면 환불이 가능합니다. 다만 소비자의 확인 소홀 '
#  '등 과실이 있을 경우 책임 비율이 조정될 수 있으므로, 증거 수집과 전문가 상담을 권장합니다.')
#
# [참조된 원본 문서]
# - 페이지: 100
# - 페이지: 101
# - 페이지: 102
# - 페이지: 103
# - 페이지: 4
#
# ==================== 테스트 질문 4 ====================
# 질문: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
# 예상 분쟁 유형: 게임
# --------------------------------------------------
# [전문 법률 조언 답변] (생성 시간: 9.35초)
# ('### 전문 법률 조언: 미성년자의 부모 동의 없이 게임 아이템 구매 시 환불 가능성  \n'
#  '\n'
#  '#### 1. **법적 근거 및 쟁점 분석**  \n'
#  '- **민법 제5조(미성년자의 능력)**: 미성년자가 법정대리인의 동의 없이 체결한 계약은 취소할 수 있습니다. 단, **민법 '
#  '제17조(무능력자의 사술)**에 따라 미성년자가 성년인 것처럼 속인 경우(예: 타인 명의 도용, 성인 행세) 계약 취소가 제한될 수 '
#  '있습니다.  \n'
#  '- **쟁점**:  \n'
#  '  - 미성년자가 **타인 명의 도용** 또는 **성인 행세**를 했는지 여부  \n'
#  '  - 게임사가 **실명 인증 등 미성년자 보호 장치**를 마련했는지 여부  \n'
#  '\n'
#  '#### 2. **사례별 적용 및 유사 판례**  \n'
#  '**(1) 타인 명의 도용 사례 (2008_부당결제대금 반환 청구)**  \n'
#  '- **사건 개요**: 미성년자가 성인 주민번호로 가입 후 아이템 구매.  \n'
#  '- **결과**:  \n'
#  '  - 게임사는 실명 인증 미비로 35% 책임 분담.  \n'
#  '  - **조정안**: 신청인(부모) 65%, 게임사 35% 부담 → **10만 원 환급**.  \n'
#  '- **시사점**:  \n'
#  '  - 미성년자 감독 소홀(부모 책임)과 게임사의 실명 인증 미비(사업자 책임)가 동시에 고려됨.  \n'
#  '\n'
#  '**(2) 성인 행세 사례 (2008_미성년자 신용카드 부정사용)**  \n'
#  '- **사건 개요**: 미성년자가 성인 아이디로 결제 후 게임머니 현금화 시도.  \n'
#  '- **결과**:  \n'
#  '  - 미성년자가 성인 행세(사술)로 판단 → **계약 취소 불가**.  \n'
#  '  - 단, 게임사는 미성년자 보호 장치 미비로 부분적 책임 인정 가능성 있음.  \n'
#  '- **시사점**:  \n'
#  '  - 미성년자가 성인처럼 행동한 경우, 게임사는 추가 확인 절차(예: 본인 인증)를 거쳐야 함.  \n'
#  '\n'
#  '**(3) 부모 동의 없이 단독 결제 사례 (2006_미성년자 결제 취소 청구)**  \n'
#  '- **사건 개요**: 초등학생이 부모 몰래 신용카드 결제.  \n'
#  '- **결과**:  \n'
#  '  - 미성년자 명의 결제분만 취소 가능 → **성인 명의 결제는 환불 거부**.  \n'
#  '- **시사점**:  \n'
#  '  - 미성년자 본인 명의 결제 시 취소 가능, 타인 명의는 사술로 간주될 수 있음.  \n'
#  '\n'
#  '#### 3. **실무적 해결 방안**  \n'
#  '**(1) 환불 가능성 판단 기준**  \n'
#  '- **① 미성년자 본인 명의 + 부모 동의 없음**  \n'
#  '  - **계약 취소 가능** (민법 제5조). 단, 게임사가 실명 인증 절차를 이행했는지 확인 필요.  \n'
#  '- **② 타인 명의 도용 또는 성인 행세**  \n'
#  '  - **계약 취소 제한적** (민법 제17조). 단, 게임사가 실명 인증 미비로 부분적 책임 질 수 있음.  \n'
#  '\n'
#  '**(2) 단계별 조치**  \n'
#  '1. **결제 내역 확인**:  \n'
#  '   - 미성년자 본인 명의인지, 타인 명의 도용 여부 확인.  \n'
#  '   - 결제 수단(신용카드, 휴대폰 등)과 결제 시점 기록 확보.  \n'
#  '2. **게임사에 환불 요청**:  \n'
#  '   - **본인 명의 결제**: "법정대리인 동의 없는 미성년자 계약"을 이유로 취소 요청.  \n'
#  '   - **타인 명의 결제**: 게임사의 실명 인증 미비 책임을 주장하여 부분 환불 협의.  \n'
#  '3. **전자거래분쟁조정위원회 신청**:  \n'
#  '   - 게임사와 협의 실패 시, 분쟁조정을 통해 책임 분담 비율(예: 부모 65% vs. 게임사 35%)을 조정받을 수 있음.  \n'
#  '4. **신용카드사 청구 철회**:  \n'
#  '   - 신용카드 결제 시, "부정사용"으로 신고하여 결제 취소 요청. 단, 미성년자가 성인 행세한 경우 어려울 수 있음.  \n'
#  '\n'
#  '**(3) 주의사항**  \n'
#  '- **증거 확보**: 결제 내역, 게임 접속 기록, 게임사와의 대화 기록 등을 보관.  \n'
#  '- **게임사 책임**: 2005년 이후 실명 인증 의무화(사례 1)를 근거로, 게임사가 인증 절차를 소홀히 한 경우 책임 주장 '
#  '가능.  \n'
#  '\n'
#  '#### 4. **결론**  \n'
#  '- **환불 가능성**은 미성년자의 행위(본인 명의 vs. 타인 명의)와 게임사의 실명 인증 이행 여부에 따라 달라집니다.  \n'
#  '- **부분 환불**이 일반적이며, 분쟁조정위원회를 통해 공정한 책임 분담을 요구할 수 있습니다.  \n'
#  '- 제시된 사례집에서는 **"미성년자가 성인 행세를 한 경우"** 또는 **"게임사가 실명 인증을 완전히 이행한 경우"**에는 환불이 '
#  '어려울 수 있음을 명시합니다.  \n'
#  '\n'
#  '> ✅ **추천 조치**: 게임사에 환불 요청 시, "미성년자 계약 취소"와 "게임사의 실명 인증 미비"를 동시에 주장하여 협의하세요. '
#  '협의 실패 시 분쟁조정위원회에 조정을 신청하는 것이 효과적입니다.')
#
# [참조된 원본 문서]
# - 페이지: 50
# - 페이지: 43
# - 페이지: 51
# - 페이지: 52
# - 페이지: 53
#
# ==================== 테스트 질문 5 ====================
# 질문: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
# 예상 분쟁 유형: 기타
# --------------------------------------------------
# [전문 법률 조언 답변] (생성 시간: 8.76초)
# ('### 전문 법률 조언: 온라인 교육 서비스 계약 해지 및 환급 요건  \n'
#  '\n'
#  '#### 1. **계약 해지 가능성**  \n'
#  '제시된 사례(2007~2010년 한국소비자원 조정결정례)에 따르면, **온라인 교육 서비스 계약은 「방문판매 등에 관한 법률」 '
#  '제29조**에 따라 **소비자가 언제든지 해지할 수 있는 "계속적 거래"**에 해당합니다.  \n'
#  '- **광고와 서비스 불일치**가 발생한 경우, 이는 **계약 내용 불이행**에 해당할 수 있으며, 소비자는 계약 해지 권한이 '
#  '있습니다(사례 2007_온라인통신교육서비스 대금 환급 요구2, 2010_화상불량으로 중도 해지한 인터넷강의 환급 요구 참조).  \n'
#  '- 단, 해지 사유는 **서비스 미제공, 품질 불량, 광고와 현저한 차이** 등 객관적 증거가 있어야 합니다(사례 2008_온라인 '
#  '통신교육서비스 이용료 환급 요구에서 서비스 중단 시 환급 인정).  \n'
#  '\n'
#  '#### 2. **환급금 산정 기준**  \n'
#  '- **「방문판매 등에 관한 법률」 제30조**는 "해지 시 소비자에게 발생한 손실을 현저히 초과하는 위약금을 청구할 수 없음"을 '
#  '명시합니다.  \n'
#  '- **소비자분쟁해결기준(공정위 고시, 인터넷콘텐츠업)**에 따라 환급금은 다음과 같이 계산됩니다:  \n'
#  '  - **이용일수 공제**: 실제 이용한 기간에 해당하는 금액만 공제 가능(사례 2007_인터넷교육서비스 중도해지 요구).  \n'
#  '  - **과도한 위약금 금지**: 가입비, 교재비, 사은품 비용 등 추가 공제는 원칙적으로 불가능합니다(사례 '
#  '2007_온라인통신교육서비스 대금 환급 요구2에서 교재비 공제 무효).  \n'
#  '  - **최대 공제 한도**: 총 이용요금의 **10% 이내** 위약금만 허용(사례 2007_인터넷교육서비스 중도해지 요구).  \n'
#  '\n'
#  '#### 3. **실무적 해결 단계**  \n'
#  '1. **증거 수집**:  \n'
#  '   - 광고 자료(홈페이지, 계약서, 이메일)와 실제 제공된 서비스의 차이를 입증할 자료(캡처, 녹화본 등)를 확보합니다.  \n'
#  '   - 이용 내역(로그인 기록, 강의 수강 확인서)을 확인하여 **미이용 기간**을 산정합니다.  \n'
#  '\n'
#  '2. **계약 해지 통보**:  \n'
#  '   - **서면(이메일, 내용증명)**으로 해지 의사를 명확히 전달하고, **광고와 다른 점**을 구체적으로 기재합니다.  \n'
#  '   - 예시: "계약 시 광고된 \'전문 강사 실시간 화상 강의\'가 제공되지 않아 계약 목적을 달성할 수 없음."  \n'
#  '\n'
#  '3. **환급 요구**:  \n'
#  '   - **소비자분쟁해결기준**에 따라 **이용일수 공제 + 10% 위약금**만 적용한 환급금을 요구합니다.  \n'
#  '   - 예시: 1년 계약(120만 원) 중 1개월 이용 시 → (120만 원 ÷ 12개월) × 11개월 × 90% = **99만 원 '
#  '환급**.  \n'
#  '\n'
#  '4. **분쟁 조정 신청**:  \n'
#  '   - 사업자가 불합리한 공제를 주장할 경우, **한국소비자원** 또는 **소비자분쟁조정위원회**에 조정을 신청합니다(사례 '
#  '2010_온라인교육 서비스 계약 해지 참조).  \n'
#  '\n'
#  '#### 4. **주의사항**  \n'
#  '- **계약서 확인**: 계약서에 "해지 시 위약금 30%" 등 불리한 조항이 있더라도, 「방문판매법」 제45조에 따라 **소비자에게 '
#  '불리한 조항은 무효**입니다(사례 2008_온라인 통신교육서비스 이용료 환급 요구).  \n'
#  '- **부분 환급 거부 시**: 사업자가 서비스 제공 사실을 주장할 경우, **이용 기록**으로 반박해야 합니다(사례 2008_온라인 '
#  '통신교육서비스 이용료 환급 요구2).  \n'
#  '\n'
#  '#### 5. **제시된 사례집 외 추가 정보**  \n'
#  '- **「전자상거래법」 제17조**에 따라 계약 체결 시 **중요한 내용을 고지하지 않은 경우** 계약 취소권이 발생할 수 있으나, '
#  '제시된 사례집에서는 확인되지 않습니다.  \n'
#  '\n'
#  '### 결론  \n'
#  '광고와 다른 서비스 제공 시 계약 해지가 가능하며, 환급금은 **이용일수 공제 + 10% 위약금 한도**로 산정해야 합니다. 사업자가 '
#  '과도한 공제를 주장할 경우 소비자분쟁조정절차를 활용하시기 바랍니다.')
#
# [참조된 원본 문서]
# - 페이지: 3
# - 페이지: 74
# - 페이지: 64
# - 페이지: 60
# - 페이지: 62
#
# ==================== 모든 테스트 완료 ====================
